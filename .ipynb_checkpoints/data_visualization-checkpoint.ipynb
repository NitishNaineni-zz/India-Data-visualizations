# %%
import geopandas as gpd
import pandas as pd

# %%
fp = "./shape files/IND_adm1.shp"

map_df = gpd.read_file(fp)

map_df.plot()

# %%
pd.
# Out:
#   File "<ipython-input-14-bc888235687a>", line 1
#     pd.
#        ^
# SyntaxError: invalid syntax

# %%
pd.
